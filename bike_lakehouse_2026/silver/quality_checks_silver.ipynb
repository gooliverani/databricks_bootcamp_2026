# %% [markdown]
# #Quality Checks
# #####Script Purpose
# ###### This script performs various quality checks for data consistency, accuracy, and standardization across the 'silver' layer. It includes checks for:
# - Null or duplicate primary keys.
# - Unwanted spaces in string fields.
# - Data standardization and consistency.
# - Invalid date ranges and orders.
# - Data consistency between related fields.
#
# #####Usage Notes:
# - Run these checks after data loading Silver Layer.
# - Investigate and resolve any discrepancies found during the checks.

# %% [markdown]
# #silver.crm_customers

# %% [markdown]
# ####Check for NULLs or Duplicates in Primary Key (Bronze)
# - Expectation: No Results

# %%
query = """
SELECT
	cst_id,
	COUNT(*)
FROM bronze.crm_cust_info
GROUP BY cst_id
HAVING COUNT(*) > 1 OR cst_id IS NULL
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cst_id</th><th>COUNT(*)</th></tr></thead><tbody><tr><td>29433</td><td>2</td></tr><tr><td>null</td><td>4</td></tr><tr><td>29449</td><td>2</td></tr><tr><td>29466</td><td>3</td></tr><tr><td>29473</td><td>2</td></tr><tr><td>29483</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# ####Check for unwanted Spaces
# - Expectation: No results

# %%
query = """
SELECT cst_lastname
FROM bronze.crm_cust_info
WHERE cst_lastname != TRIM(cst_firstname)
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cst_lastname</th></tr></thead><tbody><tr><td>Yang </td></tr><tr><td>Huang  </td></tr><tr><td> Torres</td></tr><tr><td>  Zhu</td></tr><tr><td>Johnson</td></tr><tr><td>Ruiz</td></tr><tr><td>Alvarez</td></tr><tr><td>Mehta</td></tr><tr><td>Verhoff</td></tr><tr><td>Carlson</td></tr></tbody></table></div>

# %% [markdown]
# ####Data Standardization & Consistency

# %%
query = """
SELECT DISTINCT cst_gndr
FROM bronze.crm_cust_info
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cst_gndr</th></tr></thead><tbody><tr><td>M</td></tr><tr><td>F</td></tr><tr><td>null</td></tr></tbody></table></div>

# %%
query = """
SELECT DISTINCT cst_marital_status
FROM bronze.crm_cust_info
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cst_marital_status</th></tr></thead><tbody><tr><td>M</td></tr><tr><td>S</td></tr><tr><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ####Check For Nulls or Duplicates in Primary Key (Silver)
# - Expectation: No Result

# %%
query = """
SELECT
	customer_id,
	COUNT(*)
FROM silver.crm_customers
GROUP BY customer_id
HAVING COUNT(*) > 1 OR customer_id IS NULL
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>COUNT(*)</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Check for unwanted Spaces
# - Expectation: No Result

# %%
query = """
SELECT last_name
FROM silver.crm_customers
WHERE last_name != TRIM(last_name)
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>last_name</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Data Standardization & Consistency

# %%
query = """
SELECT DISTINCT gender
FROM silver.crm_customers
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th></tr></thead><tbody><tr><td>Male</td></tr><tr><td>Female</td></tr><tr><td>n/a</td></tr></tbody></table></div>

# %%
query = """
SELECT DISTINCT marital_status
FROM silver.crm_customers
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>marital_status</th></tr></thead><tbody><tr><td>Married</td></tr><tr><td>Single</td></tr></tbody></table></div>

# %%
query = """
SELECT * FROM silver.crm_customers
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_number</th><th>first_name</th><th>last_name</th><th>marital_status</th><th>gender</th><th>created_date</th></tr></thead><tbody><tr><td>11000</td><td>AW00011000</td><td>Jon</td><td>Yang</td><td>Married</td><td>Male</td><td>2025-10-06</td></tr><tr><td>11001</td><td>AW00011001</td><td>Eugene</td><td>Huang</td><td>Single</td><td>Male</td><td>2025-10-06</td></tr><tr><td>11002</td><td>AW00011002</td><td>Ruben</td><td>Torres</td><td>Married</td><td>Male</td><td>2025-10-06</td></tr><tr><td>11003</td><td>AW00011003</td><td>Christy</td><td>Zhu</td><td>Single</td><td>Female</td><td>2025-10-06</td></tr><tr><td>11004</td><td>AW00011004</td><td>Elizabeth</td><td>Johnson</td><td>Single</td><td>Female</td><td>2025-10-06</td></tr><tr><td>11005</td><td>AW00011005</td><td>Julio</td><td>Ruiz</td><td>Single</td><td>Male</td><td>2025-10-06</td></tr><tr><td>11006</td><td>AW00011006</td><td>Janet</td><td>Alvarez</td><td>Single</td><td>Female</td><td>2025-10-06</td></tr><tr><td>11007</td><td>AW00011007</td><td>Marco</td><td>Mehta</td><td>Married</td><td>Male</td><td>2025-10-06</td></tr><tr><td>11008</td><td>AW00011008</td><td>Rob</td><td>Verhoff</td><td>Single</td><td>Female</td><td>2025-10-06</td></tr><tr><td>11009</td><td>AW00011009</td><td>Shannon</td><td>Carlson</td><td>Single</td><td>Male</td><td>2025-10-06</td></tr></tbody></table></div>

# %% [markdown]
# #silver.crm_products

# %% [markdown]
# ####Check for NULLs or Duplicates in Primary Key (Bronze)
# -- Expectation: No Results

# %%
query = """
SELECT
	prd_id,
	COUNT(*)
FROM bronze.crm_prd_info
GROUP BY prd_id
HAVING COUNT(*) > 1 OR prd_id IS NULL
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_id</th><th>COUNT(*)</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Check 'cat_id'

# %%
query = """
SELECT DISTINCT id FROM bronze.erp_px_cat_g1v2
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th></tr></thead><tbody><tr><td>AC_BR</td></tr><tr><td>AC_BS</td></tr><tr><td>AC_BC</td></tr><tr><td>AC_CL</td></tr><tr><td>AC_FE</td></tr><tr><td>AC_HE</td></tr><tr><td>AC_HP</td></tr><tr><td>AC_LI</td></tr><tr><td>AC_LO</td></tr><tr><td>AC_PA</td></tr></tbody></table></div>

# %% [markdown]
# ####Check 'sls_prd_key'

# %%
query = """
SELECT sls_prd_key FROM bronze.crm_sales_details
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_prd_key</th></tr></thead><tbody><tr><td>BK-R93R-62</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-R50B-62</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-M82B-48</td></tr><tr><td>BK-M82S-38</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R50R-52</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R50B-62</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R50B-58</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R50B-58</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-M82B-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-M82S-48</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R50B-58</td></tr><tr><td>BK-M82B-44</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-M82B-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R50R-52</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-M82S-48</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-M82S-42</td></tr><tr><td>BK-R50R-44</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-M82S-38</td></tr><tr><td>BK-M82B-48</td></tr><tr><td>BK-M82B-48</td></tr><tr><td>BK-M82S-38</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-M82S-38</td></tr><tr><td>BK-M82S-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R50B-52</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R50R-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-M82S-42</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-M82B-44</td></tr><tr><td>BK-M82B-44</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-R93R-56</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-M82S-44</td></tr><tr><td>BK-R93R-48</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-R50B-52</td></tr><tr><td>BK-R50B-44</td></tr><tr><td>BK-R93R-52</td></tr><tr><td>BK-M82B-38</td></tr><tr><td>BK-R50B-44</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-44</td></tr><tr><td>BK-M82B-42</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>BK-R93R-62</td></tr><tr><td>B ...

# %% [markdown]
# ####Check for unwanted Spaces
# - Expectation: No Result

# %%
query = """
SELECT prd_nm
FROM bronze.crm_prd_info
WHERE prd_nm != TRIM(prd_nm)
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_nm</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Check for NULLs or Negative Numbers
# - Expectation: No Result

# %%
query = """
SELECT prd_cost
FROM bronze.crm_prd_info
WHERE prd_cost < 0 OR prd_cost IS NULL
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_cost</th></tr></thead><tbody><tr><td>null</td></tr><tr><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ####Data Standardization & Consistency

# %%
query = """
SELECT DISTINCT prd_line
FROM bronze.crm_prd_info
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_line</th></tr></thead><tbody><tr><td>R </td></tr><tr><td>S </td></tr><tr><td>M </td></tr><tr><td>T </td></tr><tr><td>null</td></tr></tbody></table></div>

# %%
query = """
SELECT * FROM silver.crm_products
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_number</th><th>product_name</th><th>product_cost</th><th>product_line</th><th>start_date</th><th>end_date</th><th>category_id</th></tr></thead><tbody><tr><td>601</td><td>BB-7421</td><td>LL Bottom Bracket</td><td>24</td><td>n/a</td><td>2013-07-01</td><td>null</td><td>CO_BB</td></tr><tr><td>602</td><td>BB-8107</td><td>ML Bottom Bracket</td><td>45</td><td>n/a</td><td>2013-07-01</td><td>null</td><td>CO_BB</td></tr><tr><td>603</td><td>BB-9108</td><td>HL Bottom Bracket</td><td>54</td><td>n/a</td><td>2013-07-01</td><td>null</td><td>CO_BB</td></tr><tr><td>478</td><td>BC-M005</td><td>Mountain Bottle Cage</td><td>4</td><td>Mountain</td><td>2013-07-01</td><td>null</td><td>AC_BC</td></tr><tr><td>479</td><td>BC-R205</td><td>Road Bottle Cage</td><td>3</td><td>Road</td><td>2013-07-01</td><td>null</td><td>AC_BC</td></tr><tr><td>596</td><td>BK-M18B-40</td><td>Mountain-500 Black- 40</td><td>295</td><td>Mountain</td><td>2013-07-01</td><td>null</td><td>BI_MB</td></tr><tr><td>597</td><td>BK-M18B-42</td><td>Mountain-500 Black- 42</td><td>295</td><td>Mountain</td><td>2013-07-01</td><td>null</td><td>BI_MB</td></tr><tr><td>598</td><td>BK-M18B-44</td><td>Mountain-500 Black- 44</td><td>295</td><td>Mountain</td><td>2013-07-01</td><td>null</td><td>BI_MB</td></tr><tr><td>599</td><td>BK-M18B-48</td><td>Mountain-500 Black- 48</td><td>295</td><td>Mountain</td><td>2013-07-01</td><td>null</td><td>BI_MB</td></tr><tr><td>600</td><td>BK-M18B-52</td><td>Mountain-500 Black- 52</td><td>295</td><td>Mountain</td><td>2013-07-01</td><td>null</td><td>BI_MB</td></tr></tbody></table></div>

# %% [markdown]
# ####Check for Invalid Date Orders

# %%
query = """
SELECT * 
FROM bronze.crm_prd_info
WHERE prd_end_dt < prd_start_dt
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_id</th><th>prd_key</th><th>prd_nm</th><th>prd_cost</th><th>prd_line</th><th>prd_start_dt</th><th>prd_end_dt</th></tr></thead><tbody><tr><td>212</td><td>AC-HE-HL-U509-R</td><td>Sport-100 Helmet- Red</td><td>12</td><td>S </td><td>2011-07-01</td><td>2007-12-28</td></tr><tr><td>213</td><td>AC-HE-HL-U509-R</td><td>Sport-100 Helmet- Red</td><td>14</td><td>S </td><td>2012-07-01</td><td>2008-12-27</td></tr><tr><td>215</td><td>AC-HE-HL-U509</td><td>Sport-100 Helmet- Black</td><td>12</td><td>S </td><td>2011-07-01</td><td>2007-12-28</td></tr><tr><td>216</td><td>AC-HE-HL-U509</td><td>Sport-100 Helmet- Black</td><td>14</td><td>S </td><td>2012-07-01</td><td>2008-12-27</td></tr><tr><td>218</td><td>CL-SO-SO-B909-M</td><td>Mountain Bike Socks- M</td><td>3</td><td>M </td><td>2011-07-01</td><td>2007-12-28</td></tr><tr><td>219</td><td>CL-SO-SO-B909-L</td><td>Mountain Bike Socks- L</td><td>3</td><td>M </td><td>2011-07-01</td><td>2007-12-28</td></tr><tr><td>220</td><td>AC-HE-HL-U509-B</td><td>Sport-100 Helmet- Blue</td><td>12</td><td>S </td><td>2011-07-01</td><td>2007-12-28</td></tr><tr><td>221</td><td>AC-HE-HL-U509-B</td><td>Sport-100 Helmet- Blue</td><td>14</td><td>S </td><td>2012-07-01</td><td>2008-12-27</td></tr><tr><td>223</td><td>CL-CA-CA-1098</td><td>AWC Logo Cap</td><td>6</td><td>S </td><td>2011-07-01</td><td>2007-12-28</td></tr><tr><td>224</td><td>CL-CA-CA-1098</td><td>AWC Logo Cap</td><td>5</td><td>S </td><td>2012-07-01</td><td>2008-12-27</td></tr></tbody></table></div>

# %%
query = """
SELECT
	prd_id,
	prd_key,
	prd_nm,
	prd_start_dt,
	prd_end_dt,
	LEAD(prd_start_dt) OVER (PARTITION BY prd_key ORDER BY prd_start_dt) - 1 AS prd_end_dt_test
FROM bronze.crm_prd_info
WHERE prd_key IN ('AC-HE-HL-U509-R', 'AC-HE-HL-U509')
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_id</th><th>prd_key</th><th>prd_nm</th><th>prd_start_dt</th><th>prd_end_dt</th><th>prd_end_dt_test</th></tr></thead><tbody><tr><td>215</td><td>AC-HE-HL-U509</td><td>Sport-100 Helmet- Black</td><td>2011-07-01</td><td>2007-12-28</td><td>2012-06-30</td></tr><tr><td>216</td><td>AC-HE-HL-U509</td><td>Sport-100 Helmet- Black</td><td>2012-07-01</td><td>2008-12-27</td><td>2013-06-30</td></tr><tr><td>217</td><td>AC-HE-HL-U509</td><td>Sport-100 Helmet- Black</td><td>2013-07-01</td><td>null</td><td>null</td></tr><tr><td>212</td><td>AC-HE-HL-U509-R</td><td>Sport-100 Helmet- Red</td><td>2011-07-01</td><td>2007-12-28</td><td>2012-06-30</td></tr><tr><td>213</td><td>AC-HE-HL-U509-R</td><td>Sport-100 Helmet- Red</td><td>2012-07-01</td><td>2008-12-27</td><td>2013-06-30</td></tr><tr><td>214</td><td>AC-HE-HL-U509-R</td><td>Sport-100 Helmet- Red</td><td>2013-07-01</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# #silver.crm_sales_details

# %% [markdown]
# ####Check for Invalid Dates (Bronze)
# - Expectation: No Invalid Dates

# %%
query = """
SELECT
	NULLIF(sls_order_dt, 0) AS sls_order_dt
FROM bronze.crm_sales_details
WHERE sls_order_dt = 0
OR LEN(sls_order_dt) != 8
OR sls_order_dt > 20500101
OR sls_order_dt < 19000101
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_order_dt</th></tr></thead><tbody><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr></tbody></table></div>

# %%
query = """
SELECT
	NULLIF(sls_ship_dt, 0) AS sls_ship_dt
FROM bronze.crm_sales_details
WHERE sls_ship_dt = 0
OR LEN(sls_ship_dt) != 8
OR sls_ship_dt > 20500101
OR sls_ship_dt < 19000101
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_ship_dt</th></tr></thead><tbody></tbody></table></div>

# %%
query = """
SELECT
	NULLIF(sls_due_dt, 0) AS sls_due_dt
FROM bronze.crm_sales_details
WHERE sls_due_dt = 0
OR LEN(sls_due_dt) != 8
OR sls_due_dt > 20500101
OR sls_due_dt < 19000101
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_due_dt</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Check for Invalid Date Orders (Order Date > Shipping/Due Dates)
# - Expectation: No Results

# %%
query = """
SELECT
	*
FROM bronze.crm_sales_details
WHERE sls_order_dt > sls_ship_dt
OR sls_order_dt > sls_due_dt
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_ord_num</th><th>sls_prd_key</th><th>sls_cust_id</th><th>sls_order_dt</th><th>sls_ship_dt</th><th>sls_due_dt</th><th>sls_sales</th><th>sls_quantity</th><th>sls_price</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Check Data Consistency: Sales = Quantity * Price
# - Values must not be NULL, zero, or negative.
# - Expectation: No Results

# %%
query = """
SELECT DISTINCT
    sls_sales AS old_sls_sales,
    sls_quantity,
    sls_price AS old_sls_price,
CASE
	WHEN sls_sales IS NULL OR sls_sales <= 0 OR sls_sales != sls_quantity * ABS(sls_price)
		THEN sls_quantity * ABS(sls_price)
	ELSE sls_sales
END AS sls_sales,

CASE
	WHEN sls_price IS NULL OR sls_price <= 0
		THEN sls_sales / NULLIF(sls_quantity, 0)
	ELSE sls_price
END AS sls_price
FROM bronze.crm_sales_details
WHERE sls_sales != sls_quantity * sls_price
	OR sls_sales IS NULL
	OR sls_quantity IS NULL
	OR sls_price IS NULL
	OR sls_sales <= 0 
    OR sls_quantity <= 0 
    OR sls_price <= 0
ORDER BY sls_sales, sls_quantity, sls_price
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>old_sls_sales</th><th>sls_quantity</th><th>old_sls_price</th><th>sls_sales</th><th>sls_price</th></tr></thead><tbody><tr><td>40</td><td>1</td><td>2</td><td>2</td><td>2.0</td></tr><tr><td>null</td><td>1</td><td>2</td><td>2</td><td>2.0</td></tr><tr><td>0</td><td>1</td><td>4</td><td>4</td><td>4.0</td></tr><tr><td>null</td><td>1</td><td>8</td><td>8</td><td>8.0</td></tr><tr><td>8</td><td>1</td><td>9</td><td>9</td><td>9.0</td></tr><tr><td>9</td><td>1</td><td>null</td><td>9</td><td>9.0</td></tr><tr><td>-18</td><td>1</td><td>9</td><td>9</td><td>9.0</td></tr><tr><td>null</td><td>1</td><td>9</td><td>9</td><td>9.0</td></tr><tr><td>0</td><td>1</td><td>10</td><td>10</td><td>10.0</td></tr><tr><td>null</td><td>1</td><td>10</td><td>10</td><td>10.0</td></tr></tbody></table></div>

# %% [markdown]
# ####Check for Invalid Dates (Silver)
# - Expectation: No Invalid Dates

# %%
query = """
SELECT
    order_date
FROM silver.crm_sales
WHERE CAST(order_date AS STRING) = '0'
   OR LENGTH(CAST(order_date AS STRING)) != 10 -- 'YYYY-MM-DD' format
   OR order_date > DATE('2050-01-01')
   OR order_date < DATE('1900-01-01')
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_date</th></tr></thead><tbody></tbody></table></div>

# %%
query = """
SELECT
    ship_date
FROM silver.crm_sales
WHERE CAST(ship_date AS STRING) = '0'
   OR LENGTH(CAST(ship_date AS STRING)) != 10 -- 'YYYY-MM-DD' format
   OR ship_date > DATE('2050-01-01')
   OR ship_date < DATE('1900-01-01')
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ship_date</th></tr></thead><tbody></tbody></table></div>

# %%
query = """
SELECT
    due_date
FROM silver.crm_sales
WHERE CAST(due_date AS STRING) = '0'
   OR LENGTH(CAST(due_date AS STRING)) != 10 -- 'YYYY-MM-DD' format
   OR due_date > DATE('2050-01-01')
   OR due_date < DATE('1900-01-01')
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>due_date</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Check for Invalid Date Orders (Order Date > Shipping/Due Dates)
# - Expectation: No Results

# %%
query = """
SELECT
	*
FROM silver.crm_sales
WHERE order_date > ship_date
OR order_date > due_date
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_number</th><th>product_number</th><th>customer_id</th><th>order_date</th><th>ship_date</th><th>due_date</th><th>sales_amount</th><th>quantity</th><th>price</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Check Data Consistency: Sales = Quantity * Price
# - Values must not be NULL, zero, or negative.
# - Expectation: No Results

# %%
query = """
SELECT DISTINCT 
    sales_amount,
    quantity,
    price 
FROM silver.crm_sales
WHERE sales_amount != quantity * price
   OR sales_amount IS NULL 
   OR quantity IS NULL 
   OR price IS NULL
   OR sales_amount <= 0 
   OR quantity <= 0 
   OR price <= 0
ORDER BY sales_amount, quantity, price
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sales_amount</th><th>quantity</th><th>price</th></tr></thead><tbody></tbody></table></div>

# %%
query = """
SELECT * FROM silver.crm_sales
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_number</th><th>product_number</th><th>customer_id</th><th>order_date</th><th>ship_date</th><th>due_date</th><th>sales_amount</th><th>quantity</th><th>price</th></tr></thead><tbody><tr><td>SO43697</td><td>BK-R93R-62</td><td>21768</td><td>2010-12-29</td><td>2011-01-05</td><td>2011-01-10</td><td>3578</td><td>1</td><td>3578.0</td></tr><tr><td>SO43698</td><td>BK-M82S-44</td><td>28389</td><td>2010-12-29</td><td>2011-01-05</td><td>2011-01-10</td><td>3400</td><td>1</td><td>3400.0</td></tr><tr><td>SO43699</td><td>BK-M82S-44</td><td>25863</td><td>2010-12-29</td><td>2011-01-05</td><td>2011-01-10</td><td>3400</td><td>1</td><td>3400.0</td></tr><tr><td>SO43700</td><td>BK-R50B-62</td><td>14501</td><td>2010-12-29</td><td>2011-01-05</td><td>2011-01-10</td><td>699</td><td>1</td><td>699.0</td></tr><tr><td>SO43701</td><td>BK-M82S-44</td><td>11003</td><td>2010-12-29</td><td>2011-01-05</td><td>2011-01-10</td><td>3400</td><td>1</td><td>3400.0</td></tr><tr><td>SO43702</td><td>BK-R93R-44</td><td>27645</td><td>2010-12-30</td><td>2011-01-06</td><td>2011-01-11</td><td>3578</td><td>1</td><td>3578.0</td></tr><tr><td>SO43703</td><td>BK-R93R-62</td><td>16624</td><td>2010-12-30</td><td>2011-01-06</td><td>2011-01-11</td><td>3578</td><td>1</td><td>3578.0</td></tr><tr><td>SO43704</td><td>BK-M82B-48</td><td>11005</td><td>2010-12-30</td><td>2011-01-06</td><td>2011-01-11</td><td>3375</td><td>1</td><td>3375.0</td></tr><tr><td>SO43705</td><td>BK-M82S-38</td><td>11011</td><td>2010-12-30</td><td>2011-01-06</td><td>2011-01-11</td><td>3400</td><td>1</td><td>3400.0</td></tr><tr><td>SO43706</td><td>BK-R93R-48</td><td>27621</td><td>2010-12-31</td><td>2011-01-07</td><td>2011-01-12</td><td>3578</td><td>1</td><td>3578.0</td></tr></tbody></table></div>

# %% [markdown]
# #silver.erp_customers

# %% [markdown]
# ####Identify Out-of-Range Dates (Bronze)
# - Expectation: Birthdates between 1924-01-01 and Today

# %%
query = """
SELECT DISTINCT
	bdate
FROM bronze.erp_cust_az12
WHERE bdate < '1924-01-01' OR bdate > GETDATE()
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>bdate</th></tr></thead><tbody><tr><td>2050-07-06</td></tr><tr><td>2042-02-22</td></tr><tr><td>2050-05-21</td></tr><tr><td>2038-10-17</td></tr><tr><td>2045-03-03</td></tr><tr><td>2050-11-22</td></tr><tr><td>2066-06-16</td></tr><tr><td>9999-09-13</td></tr><tr><td>2065-12-12</td></tr><tr><td>9999-11-20</td></tr><tr><td>9999-09-11</td></tr><tr><td>1916-02-10</td></tr><tr><td>9999-05-10</td></tr><tr><td>2050-09-07</td></tr><tr><td>1917-06-05</td></tr><tr><td>1918-02-11</td></tr><tr><td>1922-04-10</td></tr><tr><td>1919-03-10</td></tr><tr><td>1917-02-09</td></tr><tr><td>1919-02-14</td></tr><tr><td>1922-06-06</td></tr><tr><td>1917-09-20</td></tr><tr><td>2080-03-15</td></tr><tr><td>1923-04-14</td></tr><tr><td>1922-01-02</td></tr><tr><td>1923-08-16</td></tr><tr><td>2055-01-23</td></tr><tr><td>1918-11-08</td></tr><tr><td>1923-11-16</td></tr><tr><td>2980-03-09</td></tr><tr><td>1920-11-14</td></tr></tbody></table></div>

# %% [markdown]
# ####Data Standardization & Consistency

# %%
query = """
SELECT DISTINCT 
    gen
FROM bronze.erp_cust_az12
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gen</th></tr></thead><tbody><tr><td>Male</td></tr><tr><td>Female</td></tr><tr><td>  </td></tr><tr><td> </td></tr><tr><td>M </td></tr><tr><td>F </td></tr><tr><td>F</td></tr><tr><td>M</td></tr><tr><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ####Identify Out-of-Range Dates (Silver)
# - Expectation: Birthdates between 1926-01-01 and Today

# %%
query = """
SELECT DISTINCT
	birth_date
FROM silver.erp_customers
WHERE birth_date < '1924-01-01' OR birth_date > GETDATE()
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>birth_date</th></tr></thead><tbody><tr><td>1916-02-10</td></tr><tr><td>1917-06-05</td></tr><tr><td>1918-02-11</td></tr><tr><td>1922-04-10</td></tr><tr><td>1919-03-10</td></tr><tr><td>1917-02-09</td></tr><tr><td>1919-02-14</td></tr><tr><td>1922-06-06</td></tr><tr><td>1917-09-20</td></tr><tr><td>1923-04-14</td></tr><tr><td>1922-01-02</td></tr><tr><td>1923-08-16</td></tr><tr><td>1918-11-08</td></tr><tr><td>1923-11-16</td></tr><tr><td>1920-11-14</td></tr></tbody></table></div>

# %% [markdown]
# ####Data Standardization & Consistency

# %%
query = """
SELECT DISTINCT 
    gender 
FROM silver.erp_customers
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th></tr></thead><tbody><tr><td>Male</td></tr><tr><td>Female</td></tr><tr><td>n/a</td></tr></tbody></table></div>

# %%
query = """
SELECT * FROM silver.erp_customers
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_number</th><th>birth_date</th><th>gender</th></tr></thead><tbody><tr><td>AW00011000</td><td>1971-10-06</td><td>Male</td></tr><tr><td>AW00011001</td><td>1976-05-10</td><td>Male</td></tr><tr><td>AW00011002</td><td>1971-02-09</td><td>Male</td></tr><tr><td>AW00011003</td><td>1973-08-14</td><td>Female</td></tr><tr><td>AW00011004</td><td>1979-08-05</td><td>Female</td></tr><tr><td>AW00011005</td><td>1976-08-01</td><td>Male</td></tr><tr><td>AW00011006</td><td>1976-12-02</td><td>Female</td></tr><tr><td>AW00011007</td><td>1969-11-06</td><td>Male</td></tr><tr><td>AW00011008</td><td>1975-07-04</td><td>Female</td></tr><tr><td>AW00011009</td><td>1969-09-29</td><td>Male</td></tr></tbody></table></div>

# %% [markdown]
# #silver.erp_customer_location

# %% [markdown]
# ####Data Standardization & Consistency (Bronze)

# %%
query = """
SELECT DISTINCT 
    cntry AS old_cntry,
	CASE
		WHEN TRIM(cntry) = 'DE' THEN 'Germany'
		WHEN TRIM(cntry) IN ('US', 'USA') THEN 'United States'
		WHEN TRIM(cntry) = '' OR cntry IS NULL THEN 'n/a'
		ELSE TRIM(cntry)
	END AS cntry
FROM bronze.erp_loc_a101
ORDER BY cntry
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>old_cntry</th><th>cntry</th></tr></thead><tbody><tr><td>Australia</td><td>Australia</td></tr><tr><td>Canada</td><td>Canada</td></tr><tr><td>France</td><td>France</td></tr><tr><td>DE</td><td>Germany</td></tr><tr><td>Germany</td><td>Germany</td></tr><tr><td>United Kingdom</td><td>United Kingdom</td></tr><tr><td>USA</td><td>United States</td></tr><tr><td>United States</td><td>United States</td></tr><tr><td>US</td><td>United States</td></tr><tr><td>  </td><td>n/a</td></tr><tr><td> </td><td>n/a</td></tr><tr><td>null</td><td>n/a</td></tr><tr><td>   </td><td>n/a</td></tr></tbody></table></div>

# %% [markdown]
# ####Data Standardization & Consistency (Silver)

# %%
query = """
SELECT DISTINCT 
    country
FROM silver.erp_customer_location
ORDER BY country
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th></tr></thead><tbody><tr><td>Australia</td></tr><tr><td>Canada</td></tr><tr><td>France</td></tr><tr><td>Germany</td></tr><tr><td>United Kingdom</td></tr><tr><td>United States</td></tr><tr><td>n/a</td></tr></tbody></table></div>

# %% [markdown]
# #erp_product_category

# %% [markdown]
# ####Check for Unwanted Spaces (Bronze)
# - Expectation: No Results

# %%
query = """
SELECT 
	*
FROM bronze.erp_px_cat_g1v2
WHERE cat != TRIM(cat)
	OR subcat != TRIM(subcat)
	OR maintenance != TRIM(maintenance)
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>CAT</th><th>SUBCAT</th><th>MAINTENANCE</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Data Standardization & Consistency

# %%
query = """
SELECT DISTINCT
	maintenance
FROM bronze.erp_px_cat_g1v2
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>maintenance</th></tr></thead><tbody><tr><td>Yes</td></tr><tr><td>No</td></tr></tbody></table></div>

# %% [markdown]
# ####Data Standardization & Consistency (Silver)

# %%
query = """
SELECT DISTINCT
	maintenance_flag
FROM silver.erp_product_category
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>maintenance_flag</th></tr></thead><tbody><tr><td>true</td></tr><tr><td>false</td></tr></tbody></table></div>

# %%
query = """
SELECT * FROM silver.erp_product_category
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category_id</th><th>category</th><th>subcategory</th><th>maintenance_flag</th></tr></thead><tbody><tr><td>AC_BR</td><td>Accessories</td><td>Bike Racks</td><td>true</td></tr><tr><td>AC_BS</td><td>Accessories</td><td>Bike Stands</td><td>false</td></tr><tr><td>AC_BC</td><td>Accessories</td><td>Bottles and Cages</td><td>false</td></tr><tr><td>AC_CL</td><td>Accessories</td><td>Cleaners</td><td>true</td></tr><tr><td>AC_FE</td><td>Accessories</td><td>Fenders</td><td>false</td></tr><tr><td>AC_HE</td><td>Accessories</td><td>Helmets</td><td>true</td></tr><tr><td>AC_HP</td><td>Accessories</td><td>Hydration Packs</td><td>false</td></tr><tr><td>AC_LI</td><td>Accessories</td><td>Lights</td><td>true</td></tr><tr><td>AC_LO</td><td>Accessories</td><td>Locks</td><td>true</td></tr><tr><td>AC_PA</td><td>Accessories</td><td>Panniers</td><td>false</td></tr></tbody></table></div>
