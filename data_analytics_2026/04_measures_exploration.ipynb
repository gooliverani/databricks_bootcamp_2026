# %% [markdown]
# #Measures Exploration (Key Metrics)
# #####Purpose:
# - To calculate aggregated metrics (e.g., totals, averages) for quick insights.
# - To identify overall trends or spot anomalies.
#
# #####SQL Functions Used:
# - COUNT(), SUM(), AVG()

# %% [markdown]
# ####Find the Total Sales

# %%
query = """
SELECT SUM(sales_amount) AS total_sales FROM gold.fact_sales
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_sales</th></tr></thead><tbody><tr><td>29356250</td></tr></tbody></table></div>

# %% [markdown]
# ####Find how many items are sold

# %%
query = """
SELECT SUM(quantity) AS total_quantity FROM gold.fact_sales
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_quantity</th></tr></thead><tbody><tr><td>60423</td></tr></tbody></table></div>

# %% [markdown]
# ####Find the average selling price

# %%
query = """
SELECT ROUND(AVG(price), 0) AS avg_price FROM gold.fact_sales
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_price</th></tr></thead><tbody><tr><td>486.0</td></tr></tbody></table></div>

# %% [markdown]
# ####Find the Total number of Orders

# %%
query = """
SELECT COUNT(order_number) AS total_orders FROM gold.fact_sales
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_orders</th></tr></thead><tbody><tr><td>60398</td></tr></tbody></table></div>

# %% [markdown]
# ##### - First eliminate duplicates then count Orders

# %%
query = """
SELECT COUNT(DISTINCT order_number) AS total_orders FROM gold.fact_sales
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_orders</th></tr></thead><tbody><tr><td>27659</td></tr></tbody></table></div>

# %% [markdown]
# ##### Find orders with more than one item

# %%
query = """
SELECT * FROM gold.fact_sales
WHERE order_number IN (
    SELECT order_number FROM gold.fact_sales
    GROUP BY order_number
    HAVING COUNT(*) > 1
)
"""
df = spark.sql(query)

df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_number</th><th>product_key</th><th>customer_key</th><th>order_date</th><th>ship_date</th><th>due_date</th><th>sales_amount</th><th>quantity</th><th>price</th></tr></thead><tbody><tr><td>SO51176</td><td>142</td><td>7240</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>2443</td><td>1</td><td>2443.0</td></tr><tr><td>SO51176</td><td>105</td><td>7240</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>9</td><td>1</td><td>9.0</td></tr><tr><td>SO51177</td><td>154</td><td>16874</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>1215</td><td>1</td><td>1215.0</td></tr><tr><td>SO51177</td><td>244</td><td>16874</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>35</td><td>1</td><td>35.0</td></tr><tr><td>SO51178</td><td>123</td><td>246</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>2320</td><td>1</td><td>2320.0</td></tr><tr><td>SO51178</td><td>104</td><td>246</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>10</td><td>1</td><td>10.0</td></tr><tr><td>SO51178</td><td>295</td><td>246</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>5</td><td>1</td><td>5.0</td></tr><tr><td>SO51179</td><td>141</td><td>11431</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>2443</td><td>1</td><td>2443.0</td></tr><tr><td>SO51179</td><td>287</td><td>11431</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>33</td><td>1</td><td>33.0</td></tr><tr><td>SO51179</td><td>290</td><td>11431</td><td>2012-12-28</td><td>2013-01-04</td><td>2013-01-09</td><td>4</td><td>1</td><td>4.0</td></tr></tbody></table></div>

# %% [markdown]
# ####Find the total number of products

# %%
query = """
SELECT COUNT(product_key) AS total_products FROM gold.dim_products
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_products</th></tr></thead><tbody><tr><td>295</td></tr></tbody></table></div>

# %% [markdown]
# ###### - Always check if numbers are the same

# %%
query = """
SELECT COUNT(DISTINCT product_key) AS total_products FROM gold.dim_products
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_products</th></tr></thead><tbody><tr><td>295</td></tr></tbody></table></div>

# %% [markdown]
# ####Find the total number of customers

# %%
query = """
SELECT COUNT(customer_key) AS total_customers FROM gold.dim_customers
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_customers</th></tr></thead><tbody><tr><td>18484</td></tr></tbody></table></div>

# %% [markdown]
# ####Find the total number of customers that has placed an order
#   - There can be some customers that just registered without placing order

# %%
query = """
SELECT COUNT(DISTINCT customer_key) AS total_customers FROM gold.fact_sales
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_customers</th></tr></thead><tbody><tr><td>18484</td></tr></tbody></table></div>

# %% [markdown]
# ####Generate a Report that shows all key metrics of the business (Big numbers)

# %%
query = """
SELECT 'Total Sales' AS measure_name, SUM(sales_amount) AS measure_value FROM gold.fact_sales
UNION ALL
SELECT 'Total Quantity' AS measure_name, SUM(quantity) AS measure_value FROM gold.fact_sales
UNION ALL
SELECT 'Average Price', ROUND(AVG(price), 0) FROM gold.fact_sales
UNION ALL
SELECT 'Total Orders', COUNT(DISTINCT order_number) FROM gold.fact_sales
UNION ALL
SELECT 'Total Products', COUNT(DISTINCT product_name) FROM gold.dim_products
UNION ALL
SELECT 'Total Customers', COUNT(customer_key) FROM gold.dim_customers
"""
df = spark.sql(query)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>measure_name</th><th>measure_value</th></tr></thead><tbody><tr><td>Total Sales</td><td>2.935625E7</td></tr><tr><td>Total Quantity</td><td>60423.0</td></tr><tr><td>Average Price</td><td>486.0</td></tr><tr><td>Total Orders</td><td>27659.0</td></tr><tr><td>Total Products</td><td>295.0</td></tr><tr><td>Total Customers</td><td>18484.0</td></tr></tbody></table></div>
